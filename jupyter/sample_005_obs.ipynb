# %%
import sys

path_up = ".."
if not path_up in sys.path:
    sys.path.append(path_up)

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import dates as mdates

# %%
FONT_PATH = "../fonts/RictyDiminished-Regular.ttf"
fm.fontManager.addfont(FONT_PATH)

# FontPropertiesオブジェクト生成（名前の取得のため）
font_prop = fm.FontProperties(fname=FONT_PATH)
font_prop.get_name()

plt.rcParams["font.family"] = font_prop.get_name()

# %%
file_pkl = "../observation.pkl"
df_obs = pd.read_pickle(file_pkl)
df_obs
# Out:
#               0    1         2         3         4    5    6    7    8
# 0      0.000000  0.0  0.000000  0.000000  0.000000  0.0  1.0  0.0  0.0
# 1      0.000000  0.0  0.000000  0.000000  0.000000  0.0  1.0  0.0  0.0
# 2     -0.002694 -0.1  0.000000 -0.026933 -1.000000  0.0  1.0  0.0  0.0
# 3     -0.002694  0.0  0.000000 -0.026933 -1.000000  0.0  1.0  0.0  0.0
# 4     -0.002694  0.0  0.000000 -0.026933 -1.000000  0.0  1.0  0.0  0.0
# ...         ...  ...       ...       ...       ...  ...  ...  ...  ...
# 19382 -0.064655  0.0  0.026760  0.000000  0.000000  0.0  1.0  0.0  0.0
# 19383 -0.064655  0.0  0.028107  0.000000  0.000000  0.0  1.0  0.0  0.0
# 19384 -0.064655  0.0  0.029454  0.000000  0.000000  0.0  1.0  0.0  0.0
# 19385 -0.061961  0.1  0.031609  0.027108  0.009009  0.0  1.0  0.0  0.0
# 19386 -0.061961  0.0  0.033764  0.027108  0.009009  0.0  1.0  0.0  0.0
#
# [19387 rows x 9 columns]
